# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_parquet('higgs_boson.parquet')

# %%
df.head()
# Out:
#    EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0   100000       138.470                       51.655        97.827    27.980
# 1   100001       160.937                       68.768       103.235    48.146
# 2   100002      -999.000                      162.172       125.953    35.635
# 3   100003       143.905                       81.417        80.943     0.414
# 4   100004       175.864                       16.915       134.805    16.405
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                  0.91           124.711                2.666
# 1               -999.00          -999.000             -999.000
# 2               -999.00          -999.000             -999.000
# 3               -999.00          -999.000             -999.000
# 4               -999.00          -999.000             -999.000
#
#    DER_deltar_tau_lep  DER_pt_tot  ...  PRI_jet_num  PRI_jet_leading_pt  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   EventId                      250000 non-null  int64
#  1   DER_mass_MMC                 250000 non-null  float64
#  2   DER_mass_transverse_met_lep  250000 non-null  float64
#  3   DER_mass_vis                 250000 non-null  float64
#  4   DER_pt_h                     250000 non-null  float64
#  5   DER_deltaeta_jet_jet         250000 non-null  float64
#  6   DER_mass_jet_jet             250000 non-null  float64
#  7   DER_prodeta_jet_jet          250000 non-null  float64
#  8   DER_deltar_tau_lep           250000 non-null  float64
#  9   DER_pt_tot                   250000 non-null  float64
#  10  DER_sum_pt                   250000 non-null  float64
#  11  DER_pt_ratio_lep_tau         250000 non-null  float64
# ...

# %%
df.describe().T
# Out:
#                                 count           mean           std  \
# EventId                      250000.0  224999.500000  72168.927986
# DER_mass_MMC                 250000.0     -49.023079    406.345647
# DER_mass_transverse_met_lep  250000.0      49.239819     35.344886
# DER_mass_vis                 250000.0      81.181982     40.828691
# DER_pt_h                     250000.0      57.895962     63.655682
# DER_deltaeta_jet_jet         250000.0    -708.420675    454.480565
# DER_mass_jet_jet             250000.0    -601.237051    657.972302
# DER_prodeta_jet_jet          250000.0    -709.356603    453.019877
# DER_deltar_tau_lep           250000.0       2.373100      0.782911
# DER_pt_tot                   250000.0      18.917332     22.273494
# DER_sum_pt                   250000.0     158.432217    115.706115
# DER_pt_ratio_lep_tau         250000.0       1.437609      0.844743
# DER_met_phi_centrality       250000.0      -0.128305      1.193585
# ...

# %%
df.shape
# Out:
# (250000, 33)

# %%
df['Label'].value_counts()
# Out:
# b    164333
# s     85667
# Name: Label, dtype: int64

# %%
df['Label'].value_counts().plot(kind = 'pie', autopct = '%0.2f%%')
plt.legend(['background', 'signal'])
plt.show()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop('EventId', axis=1, inplace=True)

# %%
# will summarize the number of zeroes in each column
(df == 0).sum(axis=0)
# Out:
# DER_mass_MMC                       0
# DER_mass_transverse_met_lep        3
# DER_mass_vis                       0
# DER_pt_h                          41
# DER_deltaeta_jet_jet               6
# DER_mass_jet_jet                   0
# DER_prodeta_jet_jet               58
# DER_deltar_tau_lep                 0
# DER_pt_tot                        39
# DER_sum_pt                         0
# DER_pt_ratio_lep_tau               0
# DER_met_phi_centrality            53
# DER_lep_eta_centrality         15752
# PRI_tau_pt                         0
# PRI_tau_eta                        0
# PRI_tau_phi                       32
# PRI_lep_pt                         0
# PRI_lep_eta                       35
# PRI_lep_phi                       33
# PRI_met                            0
# PRI_met_phi                       44
# PRI_met_sumet                      0
# PRI_jet_num                    99913
# PRI_jet_leading_pt                 0
# PRI_jet_leading_eta               26
# ...

# %%
# will show the total number of zeroes in the whole dataframe
(df == 0).sum().sum()
# Out:
# 215986

# %%
(df == -999.0).any()
# Out:
# DER_mass_MMC                    True
# DER_mass_transverse_met_lep    False
# DER_mass_vis                   False
# DER_pt_h                       False
# DER_deltaeta_jet_jet            True
# DER_mass_jet_jet                True
# DER_prodeta_jet_jet             True
# DER_deltar_tau_lep             False
# DER_pt_tot                     False
# DER_sum_pt                     False
# DER_pt_ratio_lep_tau           False
# DER_met_phi_centrality         False
# DER_lep_eta_centrality          True
# PRI_tau_pt                     False
# PRI_tau_eta                    False
# PRI_tau_phi                    False
# PRI_lep_pt                     False
# PRI_lep_eta                    False
# PRI_lep_phi                    False
# PRI_met                        False
# PRI_met_phi                    False
# PRI_met_sumet                  False
# PRI_jet_num                    False
# PRI_jet_leading_pt              True
# PRI_jet_leading_eta             True
# ...

# %%
(df == -999.0).sum(axis=0)
# Out:
# DER_mass_MMC                    38114
# DER_mass_transverse_met_lep         0
# DER_mass_vis                        0
# DER_pt_h                            0
# DER_deltaeta_jet_jet           177457
# DER_mass_jet_jet               177457
# DER_prodeta_jet_jet            177457
# DER_deltar_tau_lep                  0
# DER_pt_tot                          0
# DER_sum_pt                          0
# DER_pt_ratio_lep_tau                0
# DER_met_phi_centrality              0
# DER_lep_eta_centrality         177457
# PRI_tau_pt                          0
# PRI_tau_eta                         0
# PRI_tau_phi                         0
# PRI_lep_pt                          0
# PRI_lep_eta                         0
# PRI_lep_phi                         0
# PRI_met                             0
# PRI_met_phi                         0
# PRI_met_sumet                       0
# PRI_jet_num                         0
# PRI_jet_leading_pt              99913
# PRI_jet_leading_eta             99913
# ...

# %% [markdown]
# #### 1) DER_mass_MMC

# %%
print('Mean:', df['DER_mass_MMC'].mean())
print('Median:', df['DER_mass_MMC'].median())
print('Mode:', df['DER_mass_MMC'].mode())
# Out:
# Mean: -49.023079440000004
# Median: 105.012
# Mode: 0   -999.0
# dtype: float64

# %%
(df['DER_mass_MMC'] == 0).sum()
# Out:
# 0

# %%
df['DER_mass_MMC'].value_counts()
# Out:
# -999.000    38114
#  108.914       10
#  96.819        10
#  103.762       10
#  108.957       10
#             ...
#  47.910         1
#  274.769        1
#  191.831        1
#  200.830        1
#  217.020        1
# Name: DER_mass_MMC, Length: 108338, dtype: int64

# %%
df['DER_mass_MMC'] = df['DER_mass_MMC'].replace(-999.0, 105.012)

# %% [markdown]
# #### DER_deltaeta_jet_jet

# %%
print('Mean:', df['DER_deltaeta_jet_jet'].mean())
print('Median:', df['DER_deltaeta_jet_jet'].median())
print('Mode:', df['DER_deltaeta_jet_jet'].mode())
# Out:
# Mean: -708.4206753999999
# Median: -999.0
# Mode: 0   -999.0
# dtype: float64

# %%
(df['DER_deltaeta_jet_jet'] == 0).sum()
# Out:
# 6

# %%
df['DER_deltaeta_jet_jet'].value_counts()
# Out:
# -999.000    177457
#  0.326          33
#  0.408          32
#  0.533          32
#  0.432          32
#              ...
#  6.706           1
#  6.688           1
#  7.482           1
#  7.262           1
#  7.316           1
# Name: DER_deltaeta_jet_jet, Length: 7087, dtype: int64

# %% [markdown]
# #### DER_mass_jet_jet

# %%
print('Mean:', df['DER_mass_jet_jet'].mean())
print('Median:', df['DER_mass_jet_jet'].median())
print('Mode:', df['DER_mass_jet_jet'].mode())
# Out:
# Mean: -601.2370507319998
# Median: -999.0
# Mode: 0   -999.0
# dtype: float64

# %%
(df['DER_mass_jet_jet'] == 0).sum()
# Out:
# 0

# %%
df['DER_mass_jet_jet'].value_counts()
# Out:
# -999.000    177457
#  161.729         5
#  104.928         4
#  83.358          4
#  91.095          4
#              ...
#  755.222         1
#  319.750         1
#  637.681         1
#  382.036         1
#  119.437         1
# Name: DER_mass_jet_jet, Length: 68366, dtype: int64

# %% [markdown]
# #### DER_prodeta_jet_jet

# %%
print('Mean:', df['DER_prodeta_jet_jet'].mean())
print('Median:', df['DER_prodeta_jet_jet'].median())
print('Mode:', df['DER_prodeta_jet_jet'].mode())
# Out:
# Mean: -709.3566029000002
# Median: -999.0
# Mode: 0   -999.0
# dtype: float64

# %%
(df['DER_prodeta_jet_jet'] == 0).sum()
# Out:
# 58

# %%
df['DER_prodeta_jet_jet'].value_counts()
# Out:
# -999.000    177457
#  0.000          58
# -0.004          53
#  0.003          47
# -0.003          43
#              ...
# -12.554          1
#  2.752           1
# -10.063          1
# -9.143           1
# -8.745           1
# Name: DER_prodeta_jet_jet, Length: 16593, dtype: int64

# %% [markdown]
# #### DER_lep_eta_centrality

# %%
print('Mean:', df['DER_lep_eta_centrality'].mean())
print('Median:', df['DER_lep_eta_centrality'].median())
print('Mode:', df['DER_lep_eta_centrality'].mode())
# Out:
# Mean: -708.9851891320002
# Median: -999.0
# Mode: 0   -999.0
# dtype: float64

# %%
(df['DER_lep_eta_centrality'] == 0).sum()
# Out:
# 15752

# %%
df['DER_lep_eta_centrality'].value_counts()
# Out:
# -999.000    177457
#  0.000       15752
#  1.000        1163
#  0.001        1119
#  0.999         900
#              ...
#  0.424          18
#  0.366          18
#  0.263          18
#  0.385          17
#  0.348          15
# Name: DER_lep_eta_centrality, Length: 1002, dtype: int64

# %% [markdown]
# #### PRI_jet_leading_pt

# %%
print('Mean:', df['PRI_jet_leading_pt'].mean())
print('Median:', df['PRI_jet_leading_pt'].median())
print('Mode:', df['PRI_jet_leading_pt'].mode())
# Out:
# Mean: -348.329567188
# Median: 38.96
# Mode: 0   -999.0
# dtype: float64

# %%
(df['PRI_jet_leading_pt'] == 0).sum()
# Out:
# 0

# %%
df['PRI_jet_leading_pt'].value_counts()
# Out:
# -999.000    99913
#  36.358        10
#  30.363        10
#  31.739        10
#  36.493        10
#             ...
#  62.489         1
#  72.548         1
#  53.942         1
#  129.874        1
#  141.752        1
# Name: PRI_jet_leading_pt, Length: 86590, dtype: int64

# %% [markdown]
# #### PRI_jet_leading_eta

# %%
print('Mean:', df['PRI_jet_leading_eta'].mean())
print('Median:', df['PRI_jet_leading_eta'].median())
print('Mode:', df['PRI_jet_leading_eta'].mode())
# Out:
# Mean: -399.254313892
# Median: -1.8719999999999999
# Mode: 0   -999.0
# dtype: float64

# %%
(df['PRI_jet_leading_eta'] == 0).sum()
# Out:
# 26

# %%
df['PRI_jet_leading_eta'].value_counts()
# Out:
# -999.000    99913
# -1.507         64
#  0.906         52
# -1.699         52
#  1.702         49
#             ...
# -4.305          1
# -4.028          1
# -3.996          1
#  4.472          1
# -3.880          1
# Name: PRI_jet_leading_eta, Length: 8558, dtype: int64

# %% [markdown]
# #### PRI_jet_leading_phi

# %%
print('Mean:', df['PRI_jet_leading_phi'].mean())
print('Median:', df['PRI_jet_leading_phi'].median())
print('Mode:', df['PRI_jet_leading_phi'].mode())
# Out:
# Mean: -399.25978800800004
# Median: -2.093
# Mode: 0   -999.0
# dtype: float64

# %%
(df['PRI_jet_leading_phi'] == 0).sum()
# Out:
# 19

# %%
df['PRI_jet_leading_phi'].value_counts()
# Out:
# -999.000    99913
# -0.157         46
#  2.127         44
# -1.736         42
# -2.055         42
#             ...
#  0.901          9
# -0.360          9
#  1.288          8
#  0.237          6
# -3.142          3
# Name: PRI_jet_leading_phi, Length: 6285, dtype: int64

# %% [markdown]
# #### PRI_jet_subleading_pt

# %%
print('Mean:', df['PRI_jet_subleading_pt'].mean())
print('Median:', df['PRI_jet_subleading_pt'].median())
print('Mode:', df['PRI_jet_subleading_pt'].mode())
# Out:
# Mean: -692.3812035480001
# Median: -999.0
# Mode: 0   -999.0
# dtype: float64

# %%
(df['PRI_jet_subleading_pt'] == 0).sum()
# Out:
# 0

# %%
df['PRI_jet_subleading_pt'].value_counts()
# Out:
# -999.000    177457
#  30.447         11
#  32.982         10
#  41.979          9
#  35.062          9
#              ...
#  86.964          1
#  49.171          1
#  48.587          1
#  69.729          1
#  134.344         1
# Name: PRI_jet_subleading_pt, Length: 42464, dtype: int64

# %% [markdown]
# #### PRI_jet_subleading_eta

# %%
print('Mean:', df['PRI_jet_subleading_eta'].mean())
print('Median:', df['PRI_jet_subleading_eta'].median())
print('Mode:', df['PRI_jet_subleading_eta'].mode())
# Out:
# Mean: -709.121609164
# Median: -999.0
# Mode: 0   -999.0
# dtype: float64

# %%
(df['PRI_jet_subleading_eta'] == 0).sum()
# Out:
# 9

# %%
df['PRI_jet_subleading_eta'].value_counts()
# Out:
# -999.000    177457
#  0.031          26
#  1.420          26
#  0.388          26
# -0.394          26
#              ...
# -3.985           1
# -3.934           1
# -0.298           1
#  4.213           1
#  4.282           1
# Name: PRI_jet_subleading_eta, Length: 8628, dtype: int64

# %% [markdown]
# #### PRI_jet_subleading_phi

# %%
print('Mean:', df['PRI_jet_subleading_phi'].mean())
print('Median:', df['PRI_jet_subleading_phi'].median())
print('Mode:', df['PRI_jet_subleading_phi'].mode())
# Out:
# Mean: -709.1186311359997
# Median: -999.0
# Mode: 0   -999.0
# dtype: float64

# %%
(df['PRI_jet_subleading_phi'] == 0).sum()
# Out:
# 10

# %%
df['PRI_jet_subleading_phi'].value_counts()
# Out:
# -999.000    177457
# -2.135          30
# -0.957          26
#  2.810          25
#  1.894          25
#              ...
#  1.841           3
#  2.857           2
#  3.142           2
# -3.142           2
# -2.207           1
# Name: PRI_jet_subleading_phi, Length: 6286, dtype: int64

# %%
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
new_data= df[df.columns[1:31]]
new_data.head()

for i in range(0, new_data.shape[1]):
    plt.figure()
    sns.distplot(new_data.iloc[:, i], bins=30,color="#9b59b6")
    #plt.savefig("dataname_{0}.png".format(i))
    
plt.show()

# %%
df.groupby('Label')['DER_mass_MMC'].plot(kind = 'line')
plt.legend()
plt.show()

# %%
df.groupby('Label')['DER_mass_transverse_met_lep'].plot(kind = 'line')
plt.legend()
plt.show()

# %%
df.groupby('Label')['DER_mass_vis'].plot(kind = 'line')
plt.legend()
plt.show()

# %%
cols = df.drop(['Label', 'EventId'], axis = 1).columns.tolist()
cols
# Out:
# ['DER_mass_MMC',
#  'DER_mass_transverse_met_lep',
#  'DER_mass_vis',
#  'DER_pt_h',
#  'DER_deltaeta_jet_jet',
#  'DER_mass_jet_jet',
#  'DER_prodeta_jet_jet',
#  'DER_deltar_tau_lep',
#  'DER_pt_tot',
#  'DER_sum_pt',
#  'DER_pt_ratio_lep_tau',
#  'DER_met_phi_centrality',
#  'DER_lep_eta_centrality',
#  'PRI_tau_pt',
#  'PRI_tau_eta',
#  'PRI_tau_phi',
#  'PRI_lep_pt',
#  'PRI_lep_eta',
#  'PRI_lep_phi',
#  'PRI_met',
#  'PRI_met_phi',
#  'PRI_met_sumet',
#  'PRI_jet_num',
#  'PRI_jet_leading_pt',
#  'PRI_jet_leading_eta',
#  'PRI_jet_leading_phi',
#  'PRI_jet_subleading_pt',
#  'PRI_jet_subleading_eta',
#  'PRI_jet_subleading_phi',
#  'PRI_jet_all_pt',
#  'Weight']

# %%
for col in cols:
  plt.figure()

  df.groupby('Label')[col].plot(kind = 'line', alpha = 0.6)
  plt.xlabel("Readings")
  plt.ylabel(col)
  plt.legend()
plt.show()

# %%
for col in cols:
  plt.figure()

  df.groupby('Label')[col].plot(kind = 'hist', alpha = 0.6)
  plt.title(col)
  plt.xlabel("Values")
  plt.ylabel('Density')
  plt.legend()
plt.show()

# %%
for col in cols:
  plt.figure()

  df.groupby('Label')[col].plot(kind = 'kde', alpha = 0.6)
  plt.title(col)
  plt.xlabel("Values")
  plt.ylabel('Density')
  plt.legend()
plt.show()

# %%
df_s = df[df['Label'] == 's']
plt.figure(figsize=(20, 20))
#df_s.drop(['Label', 'EventId'], axis =1).plot(kind = 'box')
plt.boxplot(df_s.drop(['Label', 'EventId'], axis =1))
#plt.xticklabels(cols[1:32])
plt.xticks([i for i in range(1, 32)], df.drop(['Label', 'EventId'], axis = 1).columns.tolist(),rotation='vertical')
plt.show()

# %%
df_s = df[df['Label'] == 'b']
plt.figure(figsize=(20, 20))
#df_s.drop(['Label', 'EventId'], axis =1).plot(kind = 'box')
plt.boxplot(df_s.drop(['Label', 'EventId'], axis =1))
#plt.xticklabels(cols[1:32])
plt.xticks([i for i in range(1, 32)], df.drop(['Label', 'EventId'], axis = 1).columns.tolist(),rotation='vertical')
plt.show()

# %%
df1 = df.copy()

# %%
df1['Label'] = df1['Label'].astype('category')

# %%
m = {'s' : 1, 'b': 0}
df1['Label'] = df1['Label'].map(m)

# %%
a = df1.drop(['Label'], axis =1)
a.corrwith(df1['Label']).plot(kind = 'bar', figsize = (20, 10), color = ['salmon'])
plt.title("Correlation between target and independent features", size = 25)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.show()

# %%
fig, ax = plt.subplots(6,5, figsize = (16, 18))
ax = ax.flatten()
for i in range(30):
    sns.distplot(df.iloc[:, i].values, ax = ax[i])
    ax[i].set_title(df.columns[i])
fig.tight_layout(pad = 2.0)

# %%
fig, ax = plt.subplots(6, 5, figsize = (16, 18))
ax = ax.flatten()
for i in range(30):
    sns.distplot(df.loc[df['PRI_jet_num'] == 0].iloc[:,i].values, ax = ax[i], label = 'jet_num=0')
    sns.distplot(df.loc[df['PRI_jet_num'] == 1].iloc[:,i].values, ax = ax[i], label = 'jet_num=1')
    sns.distplot(df.loc[df['PRI_jet_num'] == 2].iloc[:,i].values, ax = ax[i], label = 'jet_num=2')
    ax[i].set_title(df.columns[i])
    ax[i].legend()
fig.tight_layout(pad = 2.0)

# %%
corrmat = df.corr()
corrmat
# Out:
#                              DER_mass_MMC  DER_mass_transverse_met_lep  \
# DER_mass_MMC                     1.000000                     0.121331
# DER_mass_transverse_met_lep      0.121331                     1.000000
# DER_mass_vis                     0.804807                     0.190109
# DER_pt_h                         0.044962                    -0.249116
# DER_deltaeta_jet_jet             0.029343                    -0.176386
# DER_mass_jet_jet                 0.024533                    -0.190392
# DER_prodeta_jet_jet              0.029404                    -0.175942
# DER_deltar_tau_lep               0.464608                     0.043251
# DER_pt_tot                       0.017307                     0.017758
# DER_sum_pt                       0.138637                    -0.146837
# DER_pt_ratio_lep_tau             0.062635                     0.349504
# DER_met_phi_centrality           0.059554                    -0.419757
# ...

# %%
# Pearson Correlation
plt.figure(figsize=(12,15))
sns.heatmap(df.corr(method='pearson'), cbar=False, annot=True, fmt='.1f', linewidth=0.2, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# DER_lep_eta_centrality is highly correlated with DER_prodeta_jet_jet (ρ = 0.99999) Rejected
#
# DER_mass_jet_jet is highly correlated with DER_deltaeta_jet_jet (ρ = 0.94604) Rejected
#
# DER_prodeta_jet_jet is highly correlated with DER_mass_jet_jet (ρ = 0.94444) Rejected
#
# PRI_jet_all_pt is highly correlated with DER_sum_pt (ρ = 0.96563) Rejected
#
# PRI_jet_leading_eta is highly correlated with PRI_jet_leading_pt (ρ = 0.9961) Rejected
#
# PRI_jet_leading_phi is highly correlated with PRI_jet_leading_eta (ρ = 0.99999) Rejected
#
# PRI_jet_num has 99913 / 40.0% zeros Zeros
#
# PRI_jet_subleading_eta is highly correlated with PRI_jet_subleading_pt (ρ = 0.99935) Rejected
#
# PRI_jet_subleading_phi is highly correlated with PRI_jet_subleading_eta (ρ = 0.99999) Rejected
#
# PRI_jet_subleading_pt is highly correlated with DER_lep_eta_centrality (ρ = 0.99935) Rejected
#
# PRI_met_sumet is highly correlated with DER_sum_pt (ρ = 0.90448) Rejected
